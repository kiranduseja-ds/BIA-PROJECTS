# %% [markdown]
# EDA AND PREPROCESSING

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/drive/MyDrive/PROJECTS/CarPrice_Assignment.csv')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [markdown]
# # There are 10 categorical ordinal features and 16 numeric columns

# %%
df.shape
# there are 205 rows and 26 columns
# Out:
# (205, 26)

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# 1 Averge car length is 17
#
#
# 2 Maximum car height is 59.8
#
#
# 3  518 is the lowest price and 5400 is the Max price of the car

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
co=df.corr(numeric_only=True)
# corerelation is only for numeric columns hecnce numeric only

# %%
sns.heatmap(co)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,20))
sns.heatmap(co,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Highwaympg and citympg have 97% correlation so we will delete citympg

# %%
df.drop (columns=['citympg'],axis=1,inplace=True)

# %%
df.isna().sum()
# there are no missing values
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# car_id and car name are not required for predictive models so we will delete them
df.drop(columns=['car_ID','CarName'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# 0          front       88.6      168.8      64.1  ...            four
# 1          front       88.6      168.8      64.1  ...            four
# 2          front       94.5      171.2      65.5  ...             six
# 3          front       99.8      176.6      66.2  ...            four
# 4          front       99.4      176.6      66.4  ...            five
#
#    enginesize fuelsystem boreratio  stroke compressionratio  horsepower  \
# ...

# %%
df['doornumber'].value_counts()
# Out:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64

# %% [markdown]
# There are 115 car with 4 doors and 90 with 2 doors

# %%
sns.countplot(x='fueltype',data=df)
# Out:
# <Axes: xlabel='fueltype', ylabel='count'>

# %% [markdown]
# majority of the cars are gas type

# %%
sns.countplot(x='carbody',data=df)
# Out:
# <Axes: xlabel='carbody', ylabel='count'>

# %% [markdown]
# Majority of car has carbody has sedan carbody

# %%
sns.countplot(x='aspiration',data=df)
# Out:
# <Axes: xlabel='aspiration', ylabel='count'>

# %% [markdown]
# majority of car has std aspiration

# %%
sns.countplot(x='drivewheel',data=df)
# Out:
# <Axes: xlabel='drivewheel', ylabel='count'>

# %% [markdown]
# there are 3 types ofdrivewheel rwd,fwd,4wd out ofwhich majority car have fwd or rwd

# %%
sns.countplot(x='enginelocation',data=df)
# Out:
# <Axes: xlabel='enginelocation', ylabel='count'>

# %%
sns.countplot(x='enginetype',data=df)
# Out:
# <Axes: xlabel='enginetype', ylabel='count'>

# %% [markdown]
# majority has ohc enginetype

# %%
sns.countplot(x='symboling',data=df)
# Out:
# <Axes: xlabel='symboling', ylabel='count'>

# %% [markdown]
# majority car has 0 to 1 symboling

# %%
sns.countplot(x='cylindernumber',data=df)
# Out:
# <Axes: xlabel='cylindernumber', ylabel='count'>

# %% [markdown]
# majority car has 4 cylinders

# %%
sns.countplot(x='fuelsystem',data=df)
# Out:
# <Axes: xlabel='fuelsystem', ylabel='count'>

# %% [markdown]
# majority of car has mpfi fuelsystem

# %% [markdown]
# Numeric columns

# %%
sns.boxplot(y='stroke',data=df)
# Out:
# <Axes: ylabel='stroke'>

# %% [markdown]
# there are few outliers on both the side

# %%
sns.boxplot(y='horsepower',data=df)
# Out:
# <Axes: ylabel='horsepower'>

# %% [markdown]
# there are outliers in horsepower on upper side indicating large size are having large horsepower

# %%
sns.boxplot(y='enginesize',data=df)
# Out:
# <Axes: ylabel='enginesize'>

# %% [markdown]
# there are outliers in enginesize on upper side

# %%
sns.boxplot(y='peakrpm',data=df)
# Out:
# <Axes: ylabel='peakrpm'>

# %% [markdown]
# peakrpm is in normal range, there is only one outlier

# %%
sns.boxplot(y='highwaympg',data=df)
# Out:
# <Axes: ylabel='highwaympg'>

# %% [markdown]
# there are few outliers on upper side but there is no value

# %%
sns.boxplot(y='boreratio',data=df)
# Out:
# <Axes: ylabel='boreratio'>

# %% [markdown]
# bore ratio is in normal range

# %%
sns.boxplot(y='price',data=df)
# Out:
# <Axes: ylabel='price'>

# %%
df.nunique()
# Out:
# symboling             6
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# highwaympg           30
# price               189
# dtype: int64

# %%
df['doornumber'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
df['doornumber']=df['doornumber'].map({'two':2,'four':4})
# as door number is ordinal, we will replace two with 2 and four with 4

# %%
df['cylindernumber'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df['cylindernumber']=df['cylindernumber'].map({'four':4,'five':5,'six':6,'three':3,'twelve':12,'two':2,'eight':8})

# %%
df
# Out:
#      symboling fueltype aspiration  doornumber      carbody drivewheel  \
# 0            3      gas        std           2  convertible        rwd
# 1            3      gas        std           2  convertible        rwd
# 2            1      gas        std           2    hatchback        rwd
# 3            2      gas        std           4        sedan        fwd
# 4            2      gas        std           4        sedan        4wd
# ..         ...      ...        ...         ...          ...        ...
# 200         -1      gas        std           4        sedan        rwd
# 201         -1      gas      turbo           4        sedan        rwd
# 202         -1      gas        std           4        sedan        rwd
# 203         -1   diesel      turbo           4        sedan        rwd
# 204         -1      gas      turbo           4        sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for i in df.columns:
  if(df[i].dtypes=='object'):
    df[i]=le.fit_transform(df[i])
    # for loop

# %%
df
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           0           2        0           2
# 1            3         1           0           2        0           2
# 2            1         1           0           2        2           2
# 3            2         1           0           4        3           1
# 4            2         1           0           4        3           0
# ..         ...       ...         ...         ...      ...         ...
# 200         -1         1           0           4        3           2
# 201         -1         1           1           4        3           2
# 202         -1         1           0           4        3           2
# 203         -1         0           1           4        3           2
# 204         -1         1           1           4        3           2
#
#      enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# ...

# %%
df.dtypes
# Out:
# symboling             int64
# fueltype              int64
# aspiration            int64
# doornumber            int64
# carbody               int64
# drivewheel            int64
# enginelocation        int64
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype            int64
# cylindernumber        int64
# enginesize            int64
# fuelsystem            int64
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 124          3         1           1           2        2           2
# 181         -1         1           0           4        4           2
# 154          0         1           0           4        4           0
# 53           1         1           0           4        3           1
# 94           1         1           0           2        3           1
# ..         ...       ...         ...         ...      ...         ...
# 133          2         1           0           4        3           1
# 137          2         1           1           4        3           1
# 72           3         1           0           2        0           2
# 140          2         1           0           2        2           0
# 37           0         1           0           2        2           1
#
#      enginelocation  wheelbase  carlength  carwidth  ...  enginetype  \
# ...

# %%
X_test
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 78           2         1           0           2        2           1
# 97           1         1           0           4        4           1
# 151          1         1           0           2        2           1
# 44           1         1           0           2        3           1
# 40           0         1           0           4        3           1
# ..         ...       ...         ...         ...      ...         ...
# 39           0         1           0           4        3           1
# 110          0         0           1           4        4           2
# 164          1         1           0           2        2           2
# 56           3         1           0           2        2           2
# 176         -1         1           0           4        3           1
#
#      enginelocation  wheelbase  carlength  carwidth  ...  enginetype  \
# ...

# %%
y_train
# Out:
# 124    12764.0
# 181    15750.0
# 154     7898.0
# 53      6695.0
# 94      7299.0
#         ...
# 133    12170.0
# 137    18620.0
# 72     35056.0
# 140     7603.0
# 37      7895.0
# Name: price, Length: 143, dtype: float64

# %%
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44      8916.5
# 40     10295.0
#         ...
# 39      8845.0
# 110    13860.0
# 164     8238.0
# 56     11845.0
# 176    10898.0
# Name: price, Length: 62, dtype: float64

# %% [markdown]
# ### Model selection

# %% [markdown]
# 1 As the problem is of regresion and data is small linear regression is implemented
#
# 2 As data is small and can have some non linearity SVM is implemented
#
# 3 As data is samll knn is

# %%
from sklearn.linear_model import LinearRegression

# %%
li=LinearRegression()

# %%
li.fit(X_train,y_train) # model training
# Out:
# LinearRegression()

# %%
y_pred=li.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 11447022.102974163

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
kn=KNeighborsRegressor(n_neighbors=6)

# %%
kn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=6)

# %% [markdown]
# # SVM

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'kernel':['linear','poly','rbf','sigmoid']}

# %%
from sklearn.svm import SVR

# %%
sr=SVR()

# %%
gsc=GridSearchCV(estimator=sr,param_grid=param,scoring='r2')

# %%
gsc.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='r2')

# %%
y_pred=gsc.best_estimator_.predict(X_test)

# %%
r2_score(y_test,y_pred)*100
# Out:
# 81.402644958493

# %% [markdown]
# CONCLUSION

# %% [markdown]
# The dataset is about second hand car price prediction,there are 206 rows and 2 columns ,based on dataset we selected LR,SVM andKNN algorithms for modeling out of which SVM is giving best accuracy of 81.4%
